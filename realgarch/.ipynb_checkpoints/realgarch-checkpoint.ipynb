# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from scipy.optimize import minimize
import statsmodels.api as sm

plt.rcParams["figure.dpi"] = 120

# %%
pip install rpy2
# Out:
# Requirement already satisfied: rpy2 in /opt/anaconda3/lib/python3.13/site-packages (3.6.2)
# Requirement already satisfied: rpy2-rinterface>=3.6.2 in /opt/anaconda3/lib/python3.13/site-packages (from rpy2) (3.6.2)
# Requirement already satisfied: rpy2-robjects>=3.6.1 in /opt/anaconda3/lib/python3.13/site-packages (from rpy2) (3.6.1)
# Requirement already satisfied: cffi>=1.15.1 in /opt/anaconda3/lib/python3.13/site-packages (from rpy2-rinterface>=3.6.2->rpy2) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.15.1->rpy2-rinterface>=3.6.2->rpy2) (2.21)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from rpy2-robjects>=3.6.1->rpy2) (3.1.6)
# Requirement already satisfied: tzlocal in /opt/anaconda3/lib/python3.13/site-packages (from rpy2-robjects>=3.6.1->rpy2) (5.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->rpy2-robjects>=3.6.1->rpy2) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from rpy2.robjects.packages import importr
import rpy2.robjects as robjects
from rpy2.robjects import numpy2ri

utils = importr("utils")
utils.chooseCRANmirror(ind=1) # this was missing
utils.install_packages('rugarch')
rugarch = importr('rugarch')
# Out:
# Unable to determine R home: [Errno 2] No such file or directory: 'R'
# Error importing in API mode: ImportError("dlopen(/opt/anaconda3/lib/python3.13/site-packages/_rinterface_cffi_api.abi3.so, 0x0002): Library not loaded: /Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib\n  Referenced from: <21BE8260-F4D5-3597-9DD0-6953BC4DDF3D> /opt/anaconda3/lib/python3.13/site-packages/_rinterface_cffi_api.abi3.so\n  Reason: tried: '/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file), '/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file)")
# Trying to import in ABI mode.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from rpy2.robjects.packages import importr
#       2 import rpy2.robjects as robjects
#       3 from rpy2.robjects import numpy2ri
#
# File /opt/anaconda3/lib/python3.13/site-packages/rpy2/robjects/__init__.py:17
#      15 import typing
#      16 import warnings
# ---> 17 import rpy2.rinterface as rinterface
#      18 import rpy2.rinterface_lib.embedded
#      19 import rpy2.rinterface_lib.openrlib
#
# File /opt/anaconda3/lib/python3.13/site-packages/rpy2/rinterface/__init__.py:24
#      22 import warnings
#      23 from typing import Union
# ---> 24 from rpy2.rinterface_lib import openrlib
#      25 import rpy2.rinterface_lib._rinterface_capi as _rinterface
#      26 import rpy2.rinterface_lib.embedded as embedded
#
# File /opt/anaconda3/lib/python3.13/site-packages/rpy2/rinterface_lib/openrlib.py:93
#      91     rlib = _rinterface_cffi.lib
#      92 else:
# ---> 93     rlib = _dlopen_rlib(R_HOME)
#      96 # R macros and functions
#      97 def _get_symbol_or_fallback(symbol: str, fallback: typing.Any):
#
# File /opt/anaconda3/lib/python3.13/site-packages/rpy2/rinterface_lib/openrlib.py:80, in _dlopen_rlib(r_home)
#      76 """Open R's shared C library.
#      77
#      78 This is only relevant in ABI mode."""
#      79 if r_home is None:
# ---> 80     raise ValueError('r_home is None. '
#      81                      'Try python -m rpy2.situation')
#      82 lib_path = rpy2.situation.get_rlib_path(r_home, platform.system())
#      83 if lib_path is None:
#
# ValueError: r_home is None. Try python -m rpy2.situation

# %%
rv = pd.read_csv('SPY.csv')
rv = rv[["Date", "Volatility", "Type"]]
rv.rename(columns={"Volatility": "RV_daily"},inplace=True)
rv = rv[rv['Type'] == 'QMLE-Trade']
rv.drop(columns=['Type'], inplace=True)
rv = rv.set_index("Date")
rv.index = pd.to_datetime(rv.index)
rv.index.name = "date"

rv.head()
# Out:
#             RV_daily
# date
# 1996-01-02  0.140261
# 1996-01-03  0.082399
# 1996-01-04  0.211454
# 1996-01-05  0.022647
# 1996-01-09  0.228727

# %%
# PERMNO = 84398 for SPY
ret = pd.read_csv("returns (crsp).csv")
ret.columns = ret.columns.str.strip()

date_col = "date" if "date" in ret.columns else "Date"
ret_col  = "RET" if "RET" in ret.columns else "RETX"  # prefer RET, fallback to RETX

ret = ret[[date_col, "PERMNO", ret_col]].copy()
ret = ret[ret["PERMNO"] == 84398].drop(columns=["PERMNO"])

ret[date_col] = pd.to_datetime(ret[date_col], format="%d/%m/%Y", errors="raise")
ret = ret.sort_values(date_col).set_index(date_col)
ret.index.name = "date"

ret["r"] = pd.to_numeric(ret[ret_col], errors="coerce")
ret.drop(columns=[ret_col], inplace=True)
ret.dropna(subset=["r"], inplace=True)

ret = ret.loc[:"2024-12-29"]

ret.head()
# Out:
#                    r
# date
# 1996-01-02  0.010673
# 1996-01-03  0.002766
# 1996-01-04 -0.009529
# 1996-01-05 -0.002025
# 1996-01-08  0.003805

# %%
df = rv.join(ret, how="inner").dropna()
df.head()
# Out:
#             RV_daily         r
# date
# 1996-01-02  0.140261  0.010673
# 1996-01-03  0.082399  0.002766
# 1996-01-04  0.211454 -0.009529
# 1996-01-05  0.022647 -0.002025
# 1996-01-09  0.228727 -0.017185
