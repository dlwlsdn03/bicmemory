# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)

# %%
# ==================== Configuration ====================
class Config:
    """Configuration class for model hyperparameters"""
    # Network architecture
    hidden_layers = [32, 16, 8]

    # Training parameters
    learning_rate = 0.001
    batch_size = 1024
    epochs = 100
    early_stopping_rounds = 10
    n_ensembles = 10

    # Data parameters
    initial_train_years = 3
    validation_years = 1
    test_months = 1

    # Lag candidates
    lag_candidates = [1, 5, 16, 22, 32, 44, 66, 88]

    # Transformation parameters
    use_log_transform = True  # Model log(RV) instead of RV directly
    target_scaler = True  # Scale target variable

    # Device
    #if torch.backends.mps.is_available(): #mps sucks...
        #device = torch.device("mps")
       # print("Using MPS")
    if torch.cuda.is_available():
        device = torch.device('cuda')
        print("Using CUDA")
    else:
        device = torch.device('cpu')
        print("Using CPU")
# Out:
# Using CPU

# %%
class MLPWithBatchNorm(nn.Module):
    """MLP with Batch Normalization - no activation on output"""
    def __init__(self, input_dim, hidden_layers):
        super(MLPWithBatchNorm, self).__init__()

        layers = []
        prev_dim = input_dim

        # Build hidden layers with batch normalization
        for hidden_dim in hidden_layers:
            layers.append(nn.Linear(prev_dim, hidden_dim))
            layers.append(nn.BatchNorm1d(hidden_dim))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(0.2))
            prev_dim = hidden_dim

        # Output layer - NO activation
        layers.append(nn.Linear(prev_dim, 1))

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        # Direct output, no activation
        # The log transform + exp inverse will ensure positivity
        return self.network(x)

# %%
# ==================== Data Preparation Functions ====================
def load_and_prepare_data(filepath='SPY.csv'):
    """Load and prepare the realized volatility data"""
    rv = pd.read_csv(filepath)
    rv = rv[["Date", "Volatility", "Type"]]
    rv.rename(columns={"Volatility": "RV_daily"}, inplace=True)
    rv = rv[rv['Type'] == 'QMLE-Trade']
    rv.drop(columns=['Type'], inplace=True)
    rv = rv.set_index("Date")
    rv.index = pd.to_datetime(rv.index)
    rv.index.name = "date"

    print(f"Data loaded: {len(rv)} observations")
    print(f"Date range: {rv.index.min()} to {rv.index.max()}")

    return rv

def create_lagged_features(data, lags):
    """Create lagged features for the model"""
    df = data.copy()

    # Create lagged features
    for lag in lags:
        df[f'lag_{lag}'] = df['RV_daily'].shift(lag)

    # Remove rows with NaN values (from lagging)
    df = df.dropna()

    return df

def prepare_train_val_test_data(df, train_start, train_end, val_end, test_end):
    """Split data into train, validation, and test sets"""
    train_data = df[train_start:train_end]
    val_data = df[train_end:val_end]
    test_data = df[val_end:test_end]

    return train_data, val_data, test_data

# %%
# ==================== Model Training Functions ====================
class EarlyStopping:
    """Early stopping to prevent overfitting"""
    def __init__(self, patience=10, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0

def train_single_model(X_train, y_train, X_val, y_val, config, verbose=False):
    """Train a single MLP model"""
    # Convert to tensors
    X_train_tensor = torch.FloatTensor(X_train).to(config.device)
    y_train_tensor = torch.FloatTensor(y_train).to(config.device)
    X_val_tensor = torch.FloatTensor(X_val).to(config.device)
    y_val_tensor = torch.FloatTensor(y_val).to(config.device)

    # Create data loaders
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True)

    # Initialize model
    model = MLPWithBatchNorm(X_train.shape[1], config.hidden_layers).to(config.device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)

    # Early stopping
    early_stopping = EarlyStopping(patience=config.early_stopping_rounds)

    # Training loop
    train_losses = []
    val_losses = []

    for epoch in range(config.epochs):
        # Training phase
        model.train()
        epoch_train_loss = 0
        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            epoch_train_loss += loss.item()

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # Validation phase
        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val_tensor)
            val_loss = criterion(val_outputs, y_val_tensor).item()
            val_losses.append(val_loss)

        # Early stopping check
        early_stopping(val_loss)
        if early_stopping.early_stop:
            if verbose:
                print(f"Early stopping triggered at epoch {epoch+1}")
            break

        if verbose and (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}/{config.epochs}, Train Loss: {avg_train_loss:.6f}, Val Loss: {val_loss:.6f}")

    return model, train_losses, val_losses

def train_ensemble(X_train, y_train, X_val, y_val, config):
    """Train an ensemble of models"""
    models = []

    print(f"Training ensemble of {config.n_ensembles} models...")
    for i in range(config.n_ensembles):
        print(f"Training model {i+1}/{config.n_ensembles}")
        model, _, _ = train_single_model(X_train, y_train, X_val, y_val, config, verbose=False)
        models.append(model)

    return models

def predict_ensemble(models, X, config):
    """Make predictions using ensemble of models"""
    X_tensor = torch.FloatTensor(X).to(config.device)
    predictions = []

    for model in models:
        model.eval()
        with torch.no_grad():
            pred = model(X_tensor).cpu().numpy()
            predictions.append(pred)

    # Average predictions
    ensemble_pred = np.mean(predictions, axis=0)
    return ensemble_pred

# %%
# ==================== Evaluation Functions ====================
def calculate_mse(y_true, y_pred):
    """Calculate Mean Squared Error"""
    return mean_squared_error(y_true, y_pred)

def calculate_qlike(y_true, y_pred):
    """Calculate QLIKE loss with better numerical stability"""
    # Ensure positive values with larger epsilon for stability
    y_true = np.maximum(y_true, 1e-6)
    y_pred = np.maximum(y_pred, 1e-6)

    # QLIKE formula
    qlike = np.mean(y_true / y_pred - np.log(y_true / y_pred) - 1)

    # Cap extreme values (sanity check)
    if np.isnan(qlike) or np.isinf(qlike) or qlike > 1000:
        print(f"Warning: Extreme QLIKE value detected: {qlike}")
        return 1000.0  # Cap at 1000

    return qlike

# %%
# Calculate Information Criteria

#def calculate_BIC():

# %%
# ==================== Expanding Window Implementation ====================
def expanding_window_forecast(rv_data, config):
    """Implement expanding window forecasting with proper transformations"""
    # Create lagged features
    df_with_lags = create_lagged_features(rv_data, config.lag_candidates)

    # Initialize results storage
    all_results = []

    # Get feature columns
    feature_cols = [col for col in df_with_lags.columns if col.startswith('lag_')]

    # Start date for expanding window
    start_date = df_with_lags.index[0]
    initial_train_end = start_date + pd.DateOffset(years=config.initial_train_years)

    # Find the first valid test start date
    current_test_start = initial_train_end + pd.DateOffset(years=config.validation_years)

    print(f"\nStarting expanding window forecasting...")
    print(f"Initial training period: {start_date.date()} to {initial_train_end.date()}")
    print(f"Using log transformation: {config.use_log_transform}")
    print(f"Using target scaling: {config.target_scaler}")

    window_count = 0

    while current_test_start < df_with_lags.index[-1]:
        window_count += 1

        # Define periods
        train_end = current_test_start - pd.DateOffset(years=config.validation_years)
        val_start = train_end
        val_end = current_test_start
        test_end = min(current_test_start + pd.DateOffset(months=config.test_months),
                       df_with_lags.index[-1])

        # Get data splits
        train_data = df_with_lags[start_date:train_end]
        val_data = df_with_lags[val_start:val_end]
        test_data = df_with_lags[val_end:test_end]

        if len(test_data) == 0:
            break

        print(f"\n--- Window {window_count} ---")
        print(f"Train: {start_date.date()} to {train_end.date()} ({len(train_data)} obs)")
        print(f"Val: {val_start.date()} to {val_end.date()} ({len(val_data)} obs)")
        print(f"Test: {val_end.date()} to {test_end.date()} ({len(test_data)} obs)")

        # Prepare features
        X_train = train_data[feature_cols].values
        X_val = val_data[feature_cols].values
        X_test = test_data[feature_cols].values

        # Prepare targets with optional log transformation
        y_train_original = train_data['RV_daily'].values.reshape(-1, 1)
        y_val_original = val_data['RV_daily'].values.reshape(-1, 1)
        y_test_original = test_data['RV_daily'].values.reshape(-1, 1)

        if config.use_log_transform:
            # Apply log transformation to targets
            y_train = np.log(y_train_original + 1e-8)
            y_val = np.log(y_val_original + 1e-8)
            y_test = np.log(y_test_original + 1e-8)
        else:
            y_train = y_train_original.copy()
            y_val = y_val_original.copy()
            y_test = y_test_original.copy()

        # Standardize features
        feature_scaler = StandardScaler()
        X_train_scaled = feature_scaler.fit_transform(X_train)
        X_val_scaled = feature_scaler.transform(X_val)
        X_test_scaled = feature_scaler.transform(X_test)

        # Optionally scale targets
        if config.target_scaler:
            target_scaler = StandardScaler()
            y_train_scaled = target_scaler.fit_transform(y_train)
            y_val_scaled = target_scaler.transform(y_val)
        else:
            y_train_scaled = y_train
            y_val_scaled = y_val
            target_scaler = None

        # Train ensemble
        models = train_ensemble(X_train_scaled, y_train_scaled, X_val_scaled, y_val_scaled, config)

        # Make predictions
        train_pred_scaled = predict_ensemble(models, X_train_scaled, config)
        test_pred_scaled = predict_ensemble(models, X_test_scaled, config)

        # Inverse transform predictions
        if config.target_scaler and target_scaler is not None:
            train_pred = target_scaler.inverse_transform(train_pred_scaled)
            test_pred = target_scaler.inverse_transform(test_pred_scaled)
        else:
            train_pred = train_pred_scaled
            test_pred = test_pred_scaled

        # If log transform was used, apply exponential
        if config.use_log_transform:
            train_pred = np.exp(train_pred) - 1e-8 #added 1e-8
            test_pred = np.exp(test_pred) - 1e-8 #added 1e-8

        # Ensure predictions are positive (safety check)
        train_pred = np.maximum(train_pred, 1e-8)
        test_pred = np.maximum(test_pred, 1e-8)

        # Calculate metrics using original scale
        train_mse = calculate_mse(y_train_original, train_pred)
        test_mse = calculate_mse(y_test_original, test_pred)
        train_qlike = calculate_qlike(y_train_original.flatten(), train_pred.flatten())
        test_qlike = calculate_qlike(y_test_original.flatten(), test_pred.flatten())

        print(f"In-sample MSE: {train_mse:.6f}, QLIKE: {train_qlike:.6f}")
        print(f"Out-of-sample MSE: {test_mse:.6f}, QLIKE: {test_qlike:.6f}")

        # Store results
        for i, date in enumerate(test_data.index):
            all_results.append({
                'ticker': 'SPY',
                'date': date,
                'real_RV': y_test_original[i, 0],
                'predicted_RV': test_pred[i, 0],
                'window': window_count,
                'train_mse': train_mse,
                'test_mse': test_mse,
                'train_qlike': train_qlike,
                'test_qlike': test_qlike
            })

        # Move to next window (1 month forward)
        current_test_start = current_test_start + pd.DateOffset(months=1)

    return pd.DataFrame(all_results)

# %%
# ==================== Visualization Functions ====================
def plot_results(results_df):
    """Plot actual vs predicted RV values"""
    fig, axes = plt.subplots(2, 1, figsize=(14, 10))

    # Plot 1: Time series of actual vs predicted
    ax1 = axes[0]
    ax1.plot(results_df['date'], results_df['real_RV'], label='Actual RV', alpha=0.7, linewidth=1)
    ax1.plot(results_df['date'], results_df['predicted_RV'], label='Predicted RV', alpha=0.7, linewidth=1)
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Realized Volatility')
    ax1.set_title('MLP Neural Network: Actual vs Predicted Realized Volatility')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Plot 2: Scatter plot
    ax2 = axes[1]
    ax2.scatter(results_df['real_RV'], results_df['predicted_RV'], alpha=0.5, s=10)

    # Add diagonal line
    min_val = min(results_df['real_RV'].min(), results_df['predicted_RV'].min())
    max_val = max(results_df['real_RV'].max(), results_df['predicted_RV'].max())
    ax2.plot([min_val, max_val], [min_val, max_val], 'r--', alpha=0.5, label='Perfect Prediction')

    ax2.set_xlabel('Actual RV')
    ax2.set_ylabel('Predicted RV')
    ax2.set_title('Actual vs Predicted RV (Scatter Plot)')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('mlp_rv_forecast_results.png', dpi=300, bbox_inches='tight')
    plt.show()

def print_summary_statistics(results_df):
    """Print summary statistics of the forecasting results"""
    print("\n" + "="*60)
    print("SUMMARY STATISTICS")
    print("="*60)

    # Overall metrics
    overall_mse = calculate_mse(results_df['real_RV'], results_df['predicted_RV'])
    overall_qlike = calculate_qlike(results_df['real_RV'].values, results_df['predicted_RV'].values)

    print(f"\nOverall Out-of-Sample Performance:")
    print(f"MSE: {overall_mse:.6f}")
    print(f"QLIKE: {overall_qlike:.6f}")

    # Average metrics across windows
    avg_train_mse = results_df.groupby('window')['train_mse'].first().mean()
    avg_test_mse = results_df.groupby('window')['test_mse'].first().mean()
    avg_train_qlike = results_df.groupby('window')['train_qlike'].first().mean()
    avg_test_qlike = results_df.groupby('window')['test_qlike'].first().mean()

    print(f"\nAverage Performance Across Windows:")
    print(f"In-Sample - MSE: {avg_train_mse:.6f}, QLIKE: {avg_train_qlike:.6f}")
    print(f"Out-of-Sample - MSE: {avg_test_mse:.6f}, QLIKE: {avg_test_qlike:.6f}")

    # Correlation
    correlation = results_df['real_RV'].corr(results_df['predicted_RV'])
    print(f"\nCorrelation between Actual and Predicted: {correlation:.4f}")

    # Number of windows
    n_windows = results_df['window'].nunique()
    print(f"\nTotal number of expanding windows: {n_windows}")
    print(f"Total predictions made: {len(results_df)}")

# %%
# ==================== Main Execution ====================
def main():
    """Main execution function"""
    print("="*60)
    print("MLP NEURAL NETWORK FOR REALIZED VOLATILITY FORECASTING")
    print("="*60)

    # Initialize configuration
    config = Config()
    print(f"\nUsing device: {config.device}")

    # Load data
    print("\nLoading data...")
    rv_data = load_and_prepare_data('SPY.csv')

    # Run expanding window forecast
    results_df = expanding_window_forecast(rv_data, config)

    # Save results
    output_filename = 'mlp_rv_forecast_results.csv'
    results_df.to_csv(output_filename, index=False)
    print(f"\nResults saved to {output_filename}")

    # Print summary statistics
    print_summary_statistics(results_df)

    # Plot results
    print("\nGenerating plots...")
    plot_results(results_df)

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# MLP NEURAL NETWORK FOR REALIZED VOLATILITY FORECASTING
# ============================================================
#
# Using device: cpu
#
# Loading data...
# Data loaded: 7301 observations
# Date range: 1996-01-02 00:00:00 to 2025-04-29 00:00:00
#
# Starting expanding window forecasting...
# Initial training period: 1996-05-08 to 1999-05-08
# Using log transformation: True
# Using target scaling: True
#
# --- Window 1 ---
# Train: 1996-05-08 to 1999-05-08 (757 obs)
# Val: 1999-05-08 to 2000-05-08 (253 obs)
# Test: 2000-05-08 to 2000-06-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.005378, QLIKE: 0.105884
# Out-of-sample MSE: 0.004049, QLIKE: 0.054823
#
# --- Window 2 ---
# Train: 1996-05-08 to 1999-06-08 (778 obs)
# Val: 1999-06-08 to 2000-06-08 (255 obs)
# Test: 2000-06-08 to 2000-07-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004981, QLIKE: 0.101068
# Out-of-sample MSE: 0.000596, QLIKE: 0.014056
#
# --- Window 3 ---
# Train: 1996-05-08 to 1999-07-08 (799 obs)
# Val: 1999-07-08 to 2000-07-08 (254 obs)
# Test: 2000-07-08 to 2000-08-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004754, QLIKE: 0.096399
# Out-of-sample MSE: 0.001246, QLIKE: 0.033006
#
# --- Window 4 ---
# Train: 1996-05-08 to 1999-08-08 (820 obs)
# Val: 1999-08-08 to 2000-08-08 (254 obs)
# Test: 2000-08-08 to 2000-09-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.005637, QLIKE: 0.110126
# Out-of-sample MSE: 0.000707, QLIKE: 0.029827
#
# --- Window 5 ---
# Train: 1996-05-08 to 1999-09-08 (842 obs)
# Val: 1999-09-08 to 2000-09-08 (255 obs)
# Test: 2000-09-08 to 2000-10-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004781, QLIKE: 0.096909
# Out-of-sample MSE: 0.001840, QLIKE: 0.036446
#
# --- Window 6 ---
# Train: 1996-05-08 to 1999-10-08 (864 obs)
# Val: 1999-10-08 to 2000-10-08 (253 obs)
# Test: 2000-10-08 to 2000-11-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004822, QLIKE: 0.096925
# Out-of-sample MSE: 0.009298, QLIKE: 0.101913
#
# --- Window 7 ---
# Train: 1996-05-08 to 1999-11-08 (885 obs)
# Val: 1999-11-08 to 2000-11-08 (255 obs)
# Test: 2000-11-08 to 2000-12-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004483, QLIKE: 0.092745
# Out-of-sample MSE: 0.005958, QLIKE: 0.079319
#
# --- Window 8 ---
# Train: 1996-05-08 to 1999-12-08 (906 obs)
# Val: 1999-12-08 to 2000-12-08 (255 obs)
# Test: 2000-12-08 to 2001-01-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004511, QLIKE: 0.091348
# Out-of-sample MSE: 0.023517, QLIKE: 0.174650
#
# --- Window 9 ---
# Train: 1996-05-08 to 2000-01-08 (927 obs)
# Val: 2000-01-08 to 2001-01-08 (252 obs)
# Test: 2001-01-08 to 2001-02-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004457, QLIKE: 0.090320
# Out-of-sample MSE: 0.000986, QLIKE: 0.022869
#
# --- Window 10 ---
# Train: 1996-05-08 to 2000-02-08 (948 obs)
# Val: 2000-02-08 to 2001-02-08 (254 obs)
# Test: 2001-02-08 to 2001-03-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004557, QLIKE: 0.090903
# Out-of-sample MSE: 0.004339, QLIKE: 0.057548
#
# --- Window 11 ---
# Train: 1996-05-08 to 2000-03-08 (968 obs)
# Val: 2000-03-08 to 2001-03-08 (253 obs)
# Test: 2001-03-08 to 2001-04-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004484, QLIKE: 0.089878
# Out-of-sample MSE: 0.009478, QLIKE: 0.101215
#
# --- Window 12 ---
# Train: 1996-05-08 to 2000-04-08 (990 obs)
# Val: 2000-04-08 to 2001-04-08 (251 obs)
# Test: 2001-04-08 to 2001-05-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004529, QLIKE: 0.087741
# Out-of-sample MSE: 0.004858, QLIKE: 0.045299
#
# --- Window 13 ---
# Train: 1996-05-08 to 2000-05-08 (1010 obs)
# Val: 2000-05-08 to 2001-05-08 (253 obs)
# Test: 2001-05-08 to 2001-06-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.005051, QLIKE: 0.092594
# Out-of-sample MSE: 0.000349, QLIKE: 0.008557
#
# --- Window 14 ---
# Train: 1996-05-08 to 2000-06-08 (1032 obs)
# Val: 2000-06-08 to 2001-06-08 (253 obs)
# Test: 2001-06-08 to 2001-07-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.005475, QLIKE: 0.100429
# Out-of-sample MSE: 0.000500, QLIKE: 0.013019
#
# --- Window 15 ---
# Train: 1996-05-08 to 2000-07-08 (1052 obs)
# Val: 2000-07-08 to 2001-07-08 (251 obs)
# Test: 2001-07-08 to 2001-08-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004836, QLIKE: 0.090400
# Out-of-sample MSE: 0.000631, QLIKE: 0.014676
#
# --- Window 16 ---
# Train: 1996-05-08 to 2000-08-08 (1074 obs)
# Val: 2000-08-08 to 2001-08-08 (253 obs)
# Test: 2001-08-08 to 2001-09-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004380, QLIKE: 0.083057
# Out-of-sample MSE: 0.001772, QLIKE: 0.028198
#
# --- Window 17 ---
# Train: 1996-05-08 to 2000-09-08 (1096 obs)
# Val: 2000-09-08 to 2001-09-08 (252 obs)
# Test: 2001-09-08 to 2001-10-08 (17 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004313, QLIKE: 0.083030
# Out-of-sample MSE: 0.008593, QLIKE: 0.083639
#
# --- Window 18 ---
# Train: 1996-05-08 to 2000-10-08 (1116 obs)
# Val: 2000-10-08 to 2001-10-08 (248 obs)
# Test: 2001-10-08 to 2001-11-08 (24 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004386, QLIKE: 0.082633
# Out-of-sample MSE: 0.000980, QLIKE: 0.015437
#
# --- Window 19 ---
# Train: 1996-05-08 to 2000-11-08 (1139 obs)
# Val: 2000-11-08 to 2001-11-08 (249 obs)
# Test: 2001-11-08 to 2001-12-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004292, QLIKE: 0.080447
# Out-of-sample MSE: 0.000739, QLIKE: 0.015755
#
# --- Window 20 ---
# Train: 1996-05-08 to 2000-12-08 (1160 obs)
# Val: 2000-12-08 to 2001-12-08 (248 obs)
# Test: 2001-12-08 to 2002-01-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004589, QLIKE: 0.084228
# Out-of-sample MSE: 0.000877, QLIKE: 0.041875
#
# --- Window 21 ---
# Train: 1996-05-08 to 2001-01-08 (1179 obs)
# Val: 2001-01-08 to 2002-01-08 (249 obs)
# Test: 2002-01-08 to 2002-02-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004638, QLIKE: 0.081808
# Out-of-sample MSE: 0.000862, QLIKE: 0.018114
#
# --- Window 22 ---
# Train: 1996-05-08 to 2001-02-08 (1201 obs)
# Val: 2001-02-08 to 2002-02-08 (249 obs)
# Test: 2002-02-08 to 2002-03-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004427, QLIKE: 0.078169
# Out-of-sample MSE: 0.000690, QLIKE: 0.014725
#
# --- Window 23 ---
# Train: 1996-05-08 to 2001-03-08 (1220 obs)
# Val: 2001-03-08 to 2002-03-08 (249 obs)
# Test: 2002-03-08 to 2002-04-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004642, QLIKE: 0.081363
# Out-of-sample MSE: 0.000261, QLIKE: 0.009181
#
# --- Window 24 ---
# Train: 1996-05-08 to 2001-04-08 (1241 obs)
# Val: 2001-04-08 to 2002-04-08 (247 obs)
# Test: 2002-04-08 to 2002-05-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004469, QLIKE: 0.078118
# Out-of-sample MSE: 0.000522, QLIKE: 0.013975
#
# --- Window 25 ---
# Train: 1996-05-08 to 2001-05-08 (1262 obs)
# Val: 2001-05-08 to 2002-05-08 (249 obs)
# Test: 2002-05-08 to 2002-06-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004496, QLIKE: 0.077468
# Out-of-sample MSE: 0.000386, QLIKE: 0.009765
#
# --- Window 26 ---
# Train: 1996-05-08 to 2001-06-08 (1284 obs)
# Val: 2001-06-08 to 2002-06-08 (248 obs)
# Test: 2002-06-08 to 2002-07-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004556, QLIKE: 0.077663
# Out-of-sample MSE: 0.003158, QLIKE: 0.042941
#
# --- Window 27 ---
# Train: 1996-05-08 to 2001-07-08 (1303 obs)
# Val: 2001-07-08 to 2002-07-08 (248 obs)
# Test: 2002-07-08 to 2002-08-08 (24 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004317, QLIKE: 0.075238
# Out-of-sample MSE: 0.013427, QLIKE: 0.083723
#
# --- Window 28 ---
# Train: 1996-05-08 to 2001-08-08 (1326 obs)
# Val: 2001-08-08 to 2002-08-08 (249 obs)
# Test: 2002-08-08 to 2002-09-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004323, QLIKE: 0.075128
# Out-of-sample MSE: 0.001864, QLIKE: 0.016709
#
# --- Window 29 ---
# Train: 1996-05-08 to 2001-09-08 (1347 obs)
# Val: 2001-09-08 to 2002-09-08 (247 obs)
# Test: 2002-09-08 to 2002-10-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004247, QLIKE: 0.073525
# Out-of-sample MSE: 0.005996, QLIKE: 0.055004
#
# --- Window 30 ---
# Train: 1996-05-08 to 2001-10-08 (1364 obs)
# Val: 2001-10-08 to 2002-10-08 (253 obs)
# Test: 2002-10-08 to 2002-11-08 (24 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004258, QLIKE: 0.073137
# Out-of-sample MSE: 0.005480, QLIKE: 0.047096
#
# --- Window 31 ---
# Train: 1996-05-08 to 2001-11-08 (1387 obs)
# Val: 2001-11-08 to 2002-11-08 (253 obs)
# Test: 2002-11-08 to 2002-12-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004363, QLIKE: 0.073491
# Out-of-sample MSE: 0.001593, QLIKE: 0.021529
#
# --- Window 32 ---
# Train: 1996-05-08 to 2001-12-08 (1407 obs)
# Val: 2001-12-08 to 2002-12-08 (251 obs)
# Test: 2002-12-08 to 2003-01-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004221, QLIKE: 0.072140
# Out-of-sample MSE: 0.000464, QLIKE: 0.010015
#
# --- Window 33 ---
# Train: 1996-05-08 to 2002-01-08 (1427 obs)
# Val: 2002-01-08 to 2003-01-08 (253 obs)
# Test: 2003-01-08 to 2003-02-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004353, QLIKE: 0.073799
# Out-of-sample MSE: 0.001347, QLIKE: 0.020712
#
# --- Window 34 ---
# Train: 1996-05-08 to 2002-02-08 (1449 obs)
# Val: 2002-02-08 to 2003-02-08 (252 obs)
# Test: 2003-02-08 to 2003-03-08 (19 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004038, QLIKE: 0.069703
# Out-of-sample MSE: 0.001660, QLIKE: 0.022900
#
# --- Window 35 ---
# Train: 1996-05-08 to 2002-03-08 (1468 obs)
# Val: 2002-03-08 to 2003-03-08 (252 obs)
# Test: 2003-03-08 to 2003-04-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004044, QLIKE: 0.069590
# Out-of-sample MSE: 0.001200, QLIKE: 0.017574
#
# --- Window 36 ---
# Train: 1996-05-08 to 2002-04-08 (1488 obs)
# Val: 2002-04-08 to 2003-04-08 (254 obs)
# Test: 2003-04-08 to 2003-05-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004039, QLIKE: 0.069738
# Out-of-sample MSE: 0.000264, QLIKE: 0.005004
#
# --- Window 37 ---
# Train: 1996-05-08 to 2002-05-08 (1510 obs)
# Val: 2002-05-08 to 2003-05-08 (253 obs)
# Test: 2003-05-08 to 2003-06-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003923, QLIKE: 0.067912
# Out-of-sample MSE: 0.000326, QLIKE: 0.008105
#
# --- Window 38 ---
# Train: 1996-05-08 to 2002-06-08 (1531 obs)
# Val: 2002-06-08 to 2003-06-08 (251 obs)
# Test: 2003-06-08 to 2003-07-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003898, QLIKE: 0.067430
# Out-of-sample MSE: 0.000854, QLIKE: 0.017772
#
# --- Window 39 ---
# Train: 1996-05-08 to 2002-07-08 (1551 obs)
# Val: 2002-07-08 to 2003-07-08 (253 obs)
# Test: 2003-07-08 to 2003-08-08 (24 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003864, QLIKE: 0.066538
# Out-of-sample MSE: 0.000415, QLIKE: 0.009360
#
# --- Window 40 ---
# Train: 1996-05-08 to 2002-08-08 (1574 obs)
# Val: 2002-08-08 to 2003-08-08 (253 obs)
# Test: 2003-08-08 to 2003-09-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003887, QLIKE: 0.065533
# Out-of-sample MSE: 0.000771, QLIKE: 0.028463
#
# --- Window 41 ---
# Train: 1996-05-08 to 2002-09-08 (1594 obs)
# Val: 2002-09-08 to 2003-09-08 (252 obs)
# Test: 2003-09-08 to 2003-10-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003835, QLIKE: 0.064815
# Out-of-sample MSE: 0.000582, QLIKE: 0.019754
#
# --- Window 42 ---
# Train: 1996-05-08 to 2002-10-08 (1616 obs)
# Val: 2002-10-08 to 2003-10-08 (253 obs)
# Test: 2003-10-08 to 2003-11-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003858, QLIKE: 0.064905
# Out-of-sample MSE: 0.000257, QLIKE: 0.011452
#
# --- Window 43 ---
# Train: 1996-05-08 to 2002-11-08 (1639 obs)
# Val: 2002-11-08 to 2003-11-08 (252 obs)
# Test: 2003-11-08 to 2003-12-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003871, QLIKE: 0.064231
# Out-of-sample MSE: 0.000389, QLIKE: 0.019742
#
# --- Window 44 ---
# Train: 1996-05-08 to 2002-12-08 (1658 obs)
# Val: 2002-12-08 to 2003-12-08 (252 obs)
# Test: 2003-12-08 to 2004-01-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003887, QLIKE: 0.064103
# Out-of-sample MSE: 0.000569, QLIKE: 0.036747
#
# --- Window 45 ---
# Train: 1996-05-08 to 2003-01-08 (1679 obs)
# Val: 2003-01-08 to 2004-01-08 (253 obs)
# Test: 2004-01-08 to 2004-02-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003806, QLIKE: 0.063380
# Out-of-sample MSE: 0.000612, QLIKE: 0.027461
#
# --- Window 46 ---
# Train: 1996-05-08 to 2003-02-08 (1700 obs)
# Val: 2003-02-08 to 2004-02-08 (251 obs)
# Test: 2004-02-08 to 2004-03-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003760, QLIKE: 0.062589
# Out-of-sample MSE: 0.000521, QLIKE: 0.028182
#
# --- Window 47 ---
# Train: 1996-05-08 to 2003-03-08 (1719 obs)
# Val: 2003-03-08 to 2004-03-08 (252 obs)
# Test: 2004-03-08 to 2004-04-08 (24 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003759, QLIKE: 0.062399
# Out-of-sample MSE: 0.001044, QLIKE: 0.040533
#
# --- Window 48 ---
# Train: 1996-05-08 to 2003-04-08 (1741 obs)
# Val: 2003-04-08 to 2004-04-08 (254 obs)
# Test: 2004-04-08 to 2004-05-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003941, QLIKE: 0.064453
# Out-of-sample MSE: 0.000798, QLIKE: 0.031690
#
# --- Window 49 ---
# Train: 1996-05-08 to 2003-05-08 (1762 obs)
# Val: 2003-05-08 to 2004-05-08 (253 obs)
# Test: 2004-05-08 to 2004-06-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003687, QLIKE: 0.060981
# Out-of-sample MSE: 0.000753, QLIKE: 0.029115
#
# --- Window 50 ---
# Train: 1996-05-08 to 2003-06-08 (1782 obs)
# Val: 2003-06-08 to 2004-06-08 (253 obs)
# Test: 2004-06-08 to 2004-07-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003677, QLIKE: 0.060889
# Out-of-sample MSE: 0.000325, QLIKE: 0.021963
#
# --- Window 51 ---
# Train: 1996-05-08 to 2003-07-08 (1803 obs)
# Val: 2003-07-08 to 2004-07-08 (253 obs)
# Test: 2004-07-08 to 2004-08-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003764, QLIKE: 0.061750
# Out-of-sample MSE: 0.000362, QLIKE: 0.016595
#
# --- Window 52 ---
# Train: 1996-05-08 to 2003-08-08 (1826 obs)
# Val: 2003-08-08 to 2004-08-08 (251 obs)
# Test: 2004-08-08 to 2004-09-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003736, QLIKE: 0.061771
# Out-of-sample MSE: 0.000360, QLIKE: 0.021807
#
# --- Window 53 ---
# Train: 1996-05-08 to 2003-09-08 (1846 obs)
# Val: 2003-09-08 to 2004-09-08 (253 obs)
# Test: 2004-09-08 to 2004-10-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003534, QLIKE: 0.058922
# Out-of-sample MSE: 0.000270, QLIKE: 0.019285
#
# --- Window 54 ---
# Train: 1996-05-08 to 2003-10-08 (1868 obs)
# Val: 2003-10-08 to 2004-10-08 (253 obs)
# Test: 2004-10-08 to 2004-11-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003521, QLIKE: 0.058881
# Out-of-sample MSE: 0.000213, QLIKE: 0.012755
#
# --- Window 55 ---
# Train: 1996-05-08 to 2003-11-08 (1890 obs)
# Val: 2003-11-08 to 2004-11-08 (251 obs)
# Test: 2004-11-08 to 2004-12-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003482, QLIKE: 0.058434
# Out-of-sample MSE: 0.000298, QLIKE: 0.019605
#
# --- Window 56 ---
# Train: 1996-05-08 to 2003-12-08 (1910 obs)
# Val: 2003-12-08 to 2004-12-08 (253 obs)
# Test: 2004-12-08 to 2005-01-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003450, QLIKE: 0.058068
# Out-of-sample MSE: 0.000377, QLIKE: 0.030475
#
# --- Window 57 ---
# Train: 1996-05-08 to 2004-01-08 (1931 obs)
# Val: 2004-01-08 to 2005-01-08 (253 obs)
# Test: 2005-01-08 to 2005-02-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003451, QLIKE: 0.057812
# Out-of-sample MSE: 0.000325, QLIKE: 0.020471
#
# --- Window 58 ---
# Train: 1996-05-08 to 2004-02-08 (1951 obs)
# Val: 2004-02-08 to 2005-02-08 (253 obs)
# Test: 2005-02-08 to 2005-03-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003386, QLIKE: 0.057388
# Out-of-sample MSE: 0.000192, QLIKE: 0.014461
#
# --- Window 59 ---
# Train: 1996-05-08 to 2004-03-08 (1971 obs)
# Val: 2004-03-08 to 2005-03-08 (253 obs)
# Test: 2005-03-08 to 2005-04-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003378, QLIKE: 0.057098
# Out-of-sample MSE: 0.000187, QLIKE: 0.010489
#
# --- Window 60 ---
# Train: 1996-05-08 to 2004-04-08 (1994 obs)
# Val: 2004-04-08 to 2005-04-08 (252 obs)
# Test: 2005-04-08 to 2005-05-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003330, QLIKE: 0.056378
# Out-of-sample MSE: 0.000467, QLIKE: 0.020533
#
# --- Window 61 ---
# Train: 1996-05-08 to 2004-05-08 (2014 obs)
# Val: 2004-05-08 to 2005-05-08 (251 obs)
# Test: 2005-05-08 to 2005-06-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003339, QLIKE: 0.056893
# Out-of-sample MSE: 0.000453, QLIKE: 0.029898
#
# --- Window 62 ---
# Train: 1996-05-08 to 2004-06-08 (2035 obs)
# Val: 2004-06-08 to 2005-06-08 (253 obs)
# Test: 2005-06-08 to 2005-07-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003401, QLIKE: 0.057601
# Out-of-sample MSE: 0.000393, QLIKE: 0.025843
#
# --- Window 63 ---
# Train: 1996-05-08 to 2004-07-08 (2055 obs)
# Val: 2004-07-08 to 2005-07-08 (254 obs)
# Test: 2005-07-08 to 2005-08-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.004109, QLIKE: 0.069102
# Out-of-sample MSE: 0.000918, QLIKE: 0.057539
#
# --- Window 64 ---
# Train: 1996-05-08 to 2004-08-08 (2076 obs)
# Val: 2004-08-08 to 2005-08-08 (253 obs)
# Test: 2005-08-08 to 2005-09-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003451, QLIKE: 0.058719
# Out-of-sample MSE: 0.000324, QLIKE: 0.020682
#
# --- Window 65 ---
# Train: 1996-05-08 to 2004-09-08 (2098 obs)
# Val: 2004-09-08 to 2005-09-08 (254 obs)
# Test: 2005-09-08 to 2005-10-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003288, QLIKE: 0.056541
# Out-of-sample MSE: 0.000363, QLIKE: 0.022782
#
# --- Window 66 ---
# Train: 1996-05-08 to 2004-10-08 (2120 obs)
# Val: 2004-10-08 to 2005-10-08 (253 obs)
# Test: 2005-10-08 to 2005-11-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003289, QLIKE: 0.056650
# Out-of-sample MSE: 0.000488, QLIKE: 0.020893
#
# --- Window 67 ---
# Train: 1996-05-08 to 2004-11-08 (2141 obs)
# Val: 2004-11-08 to 2005-11-08 (254 obs)
# Test: 2005-11-08 to 2005-12-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003265, QLIKE: 0.056457
# Out-of-sample MSE: 0.000451, QLIKE: 0.036620
#
# --- Window 68 ---
# Train: 1996-05-08 to 2004-12-08 (2162 obs)
# Val: 2004-12-08 to 2005-12-08 (254 obs)
# Test: 2005-12-08 to 2006-01-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003284, QLIKE: 0.056398
# Out-of-sample MSE: 0.000466, QLIKE: 0.036852
#
# --- Window 69 ---
# Train: 1996-05-08 to 2005-01-08 (2183 obs)
# Val: 2005-01-08 to 2006-01-08 (251 obs)
# Test: 2006-01-08 to 2006-02-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003106, QLIKE: 0.054312
# Out-of-sample MSE: 0.000284, QLIKE: 0.020406
#
# --- Window 70 ---
# Train: 1996-05-08 to 2005-02-08 (2204 obs)
# Val: 2005-02-08 to 2006-02-08 (253 obs)
# Test: 2006-02-08 to 2006-03-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003286, QLIKE: 0.056707
# Out-of-sample MSE: 0.000194, QLIKE: 0.014286
#
# --- Window 71 ---
# Train: 1996-05-08 to 2005-03-08 (2223 obs)
# Val: 2005-03-08 to 2006-03-08 (253 obs)
# Test: 2006-03-08 to 2006-04-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003240, QLIKE: 0.055517
# Out-of-sample MSE: 0.000221, QLIKE: 0.015733
#
# --- Window 72 ---
# Train: 1996-05-08 to 2005-04-08 (2245 obs)
# Val: 2005-04-08 to 2006-04-08 (253 obs)
# Test: 2006-04-08 to 2006-05-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003281, QLIKE: 0.056709
# Out-of-sample MSE: 0.000398, QLIKE: 0.026597
#
# --- Window 73 ---
# Train: 1996-05-08 to 2005-05-08 (2265 obs)
# Val: 2005-05-08 to 2006-05-08 (252 obs)
# Test: 2006-05-08 to 2006-06-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003001, QLIKE: 0.052713
# Out-of-sample MSE: 0.001561, QLIKE: 0.065657
#
# --- Window 74 ---
# Train: 1996-05-08 to 2005-06-08 (2287 obs)
# Val: 2005-06-08 to 2006-06-08 (253 obs)
# Test: 2006-06-08 to 2006-07-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003069, QLIKE: 0.053990
# Out-of-sample MSE: 0.001029, QLIKE: 0.038872
#
# --- Window 75 ---
# Train: 1996-05-08 to 2005-07-08 (2308 obs)
# Val: 2005-07-08 to 2006-07-08 (252 obs)
# Test: 2006-07-08 to 2006-08-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002966, QLIKE: 0.052341
# Out-of-sample MSE: 0.000450, QLIKE: 0.019770
#
# --- Window 76 ---
# Train: 1996-05-08 to 2005-08-08 (2329 obs)
# Val: 2005-08-08 to 2006-08-08 (253 obs)
# Test: 2006-08-08 to 2006-09-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.003000, QLIKE: 0.052458
# Out-of-sample MSE: 0.000489, QLIKE: 0.036488
#
# --- Window 77 ---
# Train: 1996-05-08 to 2005-09-08 (2351 obs)
# Val: 2005-09-08 to 2006-09-08 (253 obs)
# Test: 2006-09-08 to 2006-10-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002892, QLIKE: 0.051433
# Out-of-sample MSE: 0.000241, QLIKE: 0.019296
#
# --- Window 78 ---
# Train: 1996-05-08 to 2005-10-08 (2372 obs)
# Val: 2005-10-08 to 2006-10-08 (251 obs)
# Test: 2006-10-08 to 2006-11-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002863, QLIKE: 0.050954
# Out-of-sample MSE: 0.000343, QLIKE: 0.033422
#
# --- Window 79 ---
# Train: 1996-05-08 to 2005-11-08 (2394 obs)
# Val: 2005-11-08 to 2006-11-08 (253 obs)
# Test: 2006-11-08 to 2006-12-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002955, QLIKE: 0.052695
# Out-of-sample MSE: 0.000315, QLIKE: 0.026157
#
# --- Window 80 ---
# Train: 1996-05-08 to 2005-12-08 (2415 obs)
# Val: 2005-12-08 to 2006-12-08 (253 obs)
# Test: 2006-12-08 to 2007-01-08 (19 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002841, QLIKE: 0.050906
# Out-of-sample MSE: 0.000363, QLIKE: 0.034090
#
# --- Window 81 ---
# Train: 1996-05-08 to 2006-01-08 (2434 obs)
# Val: 2006-01-08 to 2007-01-08 (251 obs)
# Test: 2007-01-08 to 2007-02-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002821, QLIKE: 0.050824
# Out-of-sample MSE: 0.000215, QLIKE: 0.019617
#
# --- Window 82 ---
# Train: 1996-05-08 to 2006-02-08 (2456 obs)
# Val: 2006-02-08 to 2007-02-08 (252 obs)
# Test: 2007-02-08 to 2007-03-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002932, QLIKE: 0.052170
# Out-of-sample MSE: 0.001622, QLIKE: 0.075535
#
# --- Window 83 ---
# Train: 1996-05-08 to 2006-03-08 (2475 obs)
# Val: 2006-03-08 to 2007-03-08 (252 obs)
# Test: 2007-03-08 to 2007-04-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002876, QLIKE: 0.051320
# Out-of-sample MSE: 0.000699, QLIKE: 0.037248
#
# --- Window 84 ---
# Train: 1996-05-08 to 2006-04-08 (2497 obs)
# Val: 2006-04-08 to 2007-04-08 (249 obs)
# Test: 2007-04-08 to 2007-05-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002781, QLIKE: 0.050394
# Out-of-sample MSE: 0.000347, QLIKE: 0.032963
#
# --- Window 85 ---
# Train: 1996-05-08 to 2006-05-08 (2517 obs)
# Val: 2006-05-08 to 2007-05-08 (252 obs)
# Test: 2007-05-08 to 2007-06-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002780, QLIKE: 0.050083
# Out-of-sample MSE: 0.000319, QLIKE: 0.021408
#
# --- Window 86 ---
# Train: 1996-05-08 to 2006-06-08 (2539 obs)
# Val: 2006-06-08 to 2007-06-08 (252 obs)
# Test: 2007-06-08 to 2007-07-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002820, QLIKE: 0.051001
# Out-of-sample MSE: 0.000662, QLIKE: 0.034462
#
# --- Window 87 ---
# Train: 1996-05-08 to 2006-07-08 (2559 obs)
# Val: 2006-07-08 to 2007-07-08 (250 obs)
# Test: 2007-07-08 to 2007-08-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002816, QLIKE: 0.050809
# Out-of-sample MSE: 0.003358, QLIKE: 0.077577
#
# --- Window 88 ---
# Train: 1996-05-08 to 2006-08-08 (2581 obs)
# Val: 2006-08-08 to 2007-08-08 (252 obs)
# Test: 2007-08-08 to 2007-09-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002702, QLIKE: 0.049310
# Out-of-sample MSE: 0.002984, QLIKE: 0.043486
#
# --- Window 89 ---
# Train: 1996-05-08 to 2006-09-08 (2603 obs)
# Val: 2006-09-08 to 2007-09-08 (251 obs)
# Test: 2007-09-08 to 2007-10-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002659, QLIKE: 0.048859
# Out-of-sample MSE: 0.001758, QLIKE: 0.060625
#
# --- Window 90 ---
# Train: 1996-05-08 to 2006-10-08 (2623 obs)
# Val: 2006-10-08 to 2007-10-08 (251 obs)
# Test: 2007-10-08 to 2007-11-08 (24 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002643, QLIKE: 0.048686
# Out-of-sample MSE: 0.001894, QLIKE: 0.049825
#
# --- Window 91 ---
# Train: 1996-05-08 to 2006-11-08 (2646 obs)
# Val: 2006-11-08 to 2007-11-08 (252 obs)
# Test: 2007-11-08 to 2007-12-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002626, QLIKE: 0.048448
# Out-of-sample MSE: 0.002025, QLIKE: 0.034544
#
# --- Window 92 ---
# Train: 1996-05-08 to 2006-12-08 (2667 obs)
# Val: 2006-12-08 to 2007-12-08 (251 obs)
# Test: 2007-12-08 to 2008-01-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002624, QLIKE: 0.048477
# Out-of-sample MSE: 0.001616, QLIKE: 0.051644
#
# --- Window 93 ---
# Train: 1996-05-08 to 2007-01-08 (2685 obs)
# Val: 2007-01-08 to 2008-01-08 (253 obs)
# Test: 2008-01-08 to 2008-02-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002598, QLIKE: 0.048332
# Out-of-sample MSE: 0.006450, QLIKE: 0.065867
#
# --- Window 94 ---
# Train: 1996-05-08 to 2007-02-08 (2707 obs)
# Val: 2007-02-08 to 2008-02-08 (253 obs)
# Test: 2008-02-08 to 2008-03-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002582, QLIKE: 0.048030
# Out-of-sample MSE: 0.000970, QLIKE: 0.013171
#
# --- Window 95 ---
# Train: 1996-05-08 to 2007-03-08 (2726 obs)
# Val: 2007-03-08 to 2008-03-08 (253 obs)
# Test: 2008-03-08 to 2008-04-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002568, QLIKE: 0.047811
# Out-of-sample MSE: 0.003291, QLIKE: 0.029362
#
# --- Window 96 ---
# Train: 1996-05-08 to 2007-04-08 (2746 obs)
# Val: 2007-04-08 to 2008-04-08 (253 obs)
# Test: 2008-04-08 to 2008-05-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002571, QLIKE: 0.048067
# Out-of-sample MSE: 0.000531, QLIKE: 0.014480
#
# --- Window 97 ---
# Train: 1996-05-08 to 2007-05-08 (2768 obs)
# Val: 2007-05-08 to 2008-05-08 (254 obs)
# Test: 2008-05-08 to 2008-06-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002552, QLIKE: 0.047761
# Out-of-sample MSE: 0.000636, QLIKE: 0.019402
#
# --- Window 98 ---
# Train: 1996-05-08 to 2007-06-08 (2790 obs)
# Val: 2007-06-08 to 2008-06-08 (252 obs)
# Test: 2008-06-08 to 2008-07-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002563, QLIKE: 0.048200
# Out-of-sample MSE: 0.001137, QLIKE: 0.018289
#
# --- Window 99 ---
# Train: 1996-05-08 to 2007-07-08 (2809 obs)
# Val: 2007-07-08 to 2008-07-08 (253 obs)
# Test: 2008-07-08 to 2008-08-08 (24 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002536, QLIKE: 0.048058
# Out-of-sample MSE: 0.001777, QLIKE: 0.021379
#
# --- Window 100 ---
# Train: 1996-05-08 to 2007-08-08 (2832 obs)
# Val: 2007-08-08 to 2008-08-08 (254 obs)
# Test: 2008-08-08 to 2008-09-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002537, QLIKE: 0.047919
# Out-of-sample MSE: 0.000998, QLIKE: 0.017832
#
# --- Window 101 ---
# Train: 1996-05-08 to 2007-09-08 (2853 obs)
# Val: 2007-09-08 to 2008-09-08 (252 obs)
# Test: 2008-09-08 to 2008-10-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002527, QLIKE: 0.047801
# Out-of-sample MSE: 0.031527, QLIKE: 0.154570
#
# --- Window 102 ---
# Train: 1996-05-08 to 2007-10-08 (2874 obs)
# Val: 2007-10-08 to 2008-10-08 (254 obs)
# Test: 2008-10-08 to 2008-11-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002568, QLIKE: 0.048511
# Out-of-sample MSE: 0.095942, QLIKE: 0.137884
#
# --- Window 103 ---
# Train: 1996-05-08 to 2007-11-08 (2897 obs)
# Val: 2007-11-08 to 2008-11-08 (253 obs)
# Test: 2008-11-08 to 2008-12-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# ...
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002540, QLIKE: 0.041958
# Out-of-sample MSE: 0.003351, QLIKE: 0.050432
#
# --- Window 263 ---
# Train: 1996-05-08 to 2021-03-08 (6242 obs)
# Val: 2021-03-08 to 2022-03-08 (249 obs)
# Test: 2022-03-08 to 2022-04-08 (24 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002532, QLIKE: 0.041543
# Out-of-sample MSE: 0.001378, QLIKE: 0.024969
#
# --- Window 264 ---
# Train: 1996-05-08 to 2021-04-08 (6262 obs)
# Val: 2021-04-08 to 2022-04-08 (251 obs)
# Test: 2022-04-08 to 2022-05-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002501, QLIKE: 0.041820
# Out-of-sample MSE: 0.003545, QLIKE: 0.042852
#
# --- Window 265 ---
# Train: 1996-05-08 to 2021-05-08 (6283 obs)
# Val: 2021-05-08 to 2022-05-08 (249 obs)
# Test: 2022-05-08 to 2022-06-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002523, QLIKE: 0.041784
# Out-of-sample MSE: 0.002987, QLIKE: 0.031263
#
# --- Window 266 ---
# Train: 1996-05-08 to 2021-06-08 (6303 obs)
# Val: 2021-06-08 to 2022-06-08 (251 obs)
# Test: 2022-06-08 to 2022-07-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002522, QLIKE: 0.041917
# Out-of-sample MSE: 0.002891, QLIKE: 0.036420
#
# --- Window 267 ---
# Train: 1996-05-08 to 2021-07-08 (6324 obs)
# Val: 2021-07-08 to 2022-07-08 (250 obs)
# Test: 2022-07-08 to 2022-08-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002531, QLIKE: 0.041985
# Out-of-sample MSE: 0.000473, QLIKE: 0.009843
#
# --- Window 268 ---
# Train: 1996-05-08 to 2021-08-08 (6345 obs)
# Val: 2021-08-08 to 2022-08-08 (249 obs)
# Test: 2022-08-08 to 2022-09-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002504, QLIKE: 0.041925
# Out-of-sample MSE: 0.000971, QLIKE: 0.027939
#
# --- Window 269 ---
# Train: 1996-05-08 to 2021-09-08 (6367 obs)
# Val: 2021-09-08 to 2022-09-08 (249 obs)
# Test: 2022-09-08 to 2022-10-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002532, QLIKE: 0.042574
# Out-of-sample MSE: 0.001918, QLIKE: 0.028191
#
# --- Window 270 ---
# Train: 1996-05-08 to 2021-10-08 (6389 obs)
# Val: 2021-10-08 to 2022-10-08 (247 obs)
# Test: 2022-10-08 to 2022-11-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002496, QLIKE: 0.042154
# Out-of-sample MSE: 0.003307, QLIKE: 0.040882
#
# --- Window 271 ---
# Train: 1996-05-08 to 2021-11-08 (6409 obs)
# Val: 2021-11-08 to 2022-11-08 (249 obs)
# Test: 2022-11-08 to 2022-12-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002484, QLIKE: 0.041839
# Out-of-sample MSE: 0.001085, QLIKE: 0.030394
#
# --- Window 272 ---
# Train: 1996-05-08 to 2021-12-08 (6430 obs)
# Val: 2021-12-08 to 2022-12-08 (248 obs)
# Test: 2022-12-08 to 2023-01-08 (19 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002503, QLIKE: 0.042355
# Out-of-sample MSE: 0.002013, QLIKE: 0.037309
#
# --- Window 273 ---
# Train: 1996-05-08 to 2022-01-08 (6450 obs)
# Val: 2022-01-08 to 2023-01-08 (245 obs)
# Test: 2023-01-08 to 2023-02-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002491, QLIKE: 0.042034
# Out-of-sample MSE: 0.001246, QLIKE: 0.029016
#
# --- Window 274 ---
# Train: 1996-05-08 to 2022-02-08 (6471 obs)
# Val: 2022-02-08 to 2023-02-08 (246 obs)
# Test: 2023-02-08 to 2023-03-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002515, QLIKE: 0.042417
# Out-of-sample MSE: 0.000587, QLIKE: 0.016381
#
# --- Window 275 ---
# Train: 1996-05-08 to 2022-03-08 (6490 obs)
# Val: 2022-03-08 to 2023-03-08 (246 obs)
# Test: 2023-03-08 to 2023-04-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002486, QLIKE: 0.042033
# Out-of-sample MSE: 0.002534, QLIKE: 0.045631
#
# --- Window 276 ---
# Train: 1996-05-08 to 2022-04-08 (6513 obs)
# Val: 2022-04-08 to 2023-04-08 (244 obs)
# Test: 2023-04-08 to 2023-05-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002511, QLIKE: 0.042383
# Out-of-sample MSE: 0.000895, QLIKE: 0.035282
#
# --- Window 277 ---
# Train: 1996-05-08 to 2022-05-08 (6532 obs)
# Val: 2022-05-08 to 2023-05-08 (245 obs)
# Test: 2023-05-08 to 2023-06-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002445, QLIKE: 0.041480
# Out-of-sample MSE: 0.000150, QLIKE: 0.008538
#
# --- Window 278 ---
# Train: 1996-05-08 to 2022-06-08 (6553 obs)
# Val: 2022-06-08 to 2023-06-08 (247 obs)
# Test: 2023-06-08 to 2023-07-08 (18 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002470, QLIKE: 0.041117
# Out-of-sample MSE: 0.000300, QLIKE: 0.020724
#
# --- Window 279 ---
# Train: 1996-05-08 to 2022-07-08 (6573 obs)
# Val: 2022-07-08 to 2023-07-08 (244 obs)
# Test: 2023-07-08 to 2023-08-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002462, QLIKE: 0.041515
# Out-of-sample MSE: 0.000180, QLIKE: 0.015877
#
# --- Window 280 ---
# Train: 1996-05-08 to 2022-08-08 (6594 obs)
# Val: 2022-08-08 to 2023-08-08 (245 obs)
# Test: 2023-08-08 to 2023-09-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002468, QLIKE: 0.041785
# Out-of-sample MSE: 0.000394, QLIKE: 0.018386
#
# --- Window 281 ---
# Train: 1996-05-08 to 2022-09-08 (6615 obs)
# Val: 2022-09-08 to 2023-09-08 (245 obs)
# Test: 2023-09-08 to 2023-10-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002452, QLIKE: 0.041455
# Out-of-sample MSE: 0.000273, QLIKE: 0.013880
#
# --- Window 282 ---
# Train: 1996-05-08 to 2022-10-08 (6635 obs)
# Val: 2022-10-08 to 2023-10-08 (243 obs)
# Test: 2023-10-08 to 2023-11-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002470, QLIKE: 0.041498
# Out-of-sample MSE: 0.000528, QLIKE: 0.018756
#
# --- Window 283 ---
# Train: 1996-05-08 to 2022-11-08 (6657 obs)
# Val: 2022-11-08 to 2023-11-08 (245 obs)
# Test: 2023-11-08 to 2023-12-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002467, QLIKE: 0.041475
# Out-of-sample MSE: 0.000214, QLIKE: 0.018845
#
# --- Window 284 ---
# Train: 1996-05-08 to 2022-12-08 (6677 obs)
# Val: 2022-12-08 to 2023-12-08 (246 obs)
# Test: 2023-12-08 to 2024-01-08 (19 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002467, QLIKE: 0.041368
# Out-of-sample MSE: 0.000339, QLIKE: 0.033076
#
# --- Window 285 ---
# Train: 1996-05-08 to 2023-01-08 (6695 obs)
# Val: 2023-01-08 to 2024-01-08 (245 obs)
# Test: 2024-01-08 to 2024-02-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002449, QLIKE: 0.041097
# Out-of-sample MSE: 0.000430, QLIKE: 0.029668
#
# --- Window 286 ---
# Train: 1996-05-08 to 2023-02-08 (6716 obs)
# Val: 2023-02-08 to 2024-02-08 (247 obs)
# Test: 2024-02-08 to 2024-03-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002438, QLIKE: 0.041119
# Out-of-sample MSE: 0.000316, QLIKE: 0.024754
#
# --- Window 287 ---
# Train: 1996-05-08 to 2023-03-08 (6735 obs)
# Val: 2023-03-08 to 2024-03-08 (248 obs)
# Test: 2024-03-08 to 2024-04-08 (19 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002435, QLIKE: 0.040850
# Out-of-sample MSE: 0.000447, QLIKE: 0.033685
#
# --- Window 288 ---
# Train: 1996-05-08 to 2023-04-08 (6756 obs)
# Val: 2023-04-08 to 2024-04-08 (244 obs)
# Test: 2024-04-08 to 2024-05-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002460, QLIKE: 0.041100
# Out-of-sample MSE: 0.000958, QLIKE: 0.043394
#
# --- Window 289 ---
# Train: 1996-05-08 to 2023-05-08 (6777 obs)
# Val: 2023-05-08 to 2024-05-08 (246 obs)
# Test: 2024-05-08 to 2024-06-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002483, QLIKE: 0.040988
# Out-of-sample MSE: 0.000228, QLIKE: 0.021713
#
# --- Window 290 ---
# Train: 1996-05-08 to 2023-06-08 (6799 obs)
# Val: 2023-06-08 to 2024-06-08 (245 obs)
# Test: 2024-06-08 to 2024-07-08 (19 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002473, QLIKE: 0.041266
# Out-of-sample MSE: 0.000323, QLIKE: 0.024707
#
# --- Window 291 ---
# Train: 1996-05-08 to 2023-07-08 (6816 obs)
# Val: 2023-07-08 to 2024-07-08 (246 obs)
# Test: 2024-07-08 to 2024-08-08 (24 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002427, QLIKE: 0.040988
# Out-of-sample MSE: 0.001182, QLIKE: 0.037387
#
# --- Window 292 ---
# Train: 1996-05-08 to 2023-08-08 (6838 obs)
# Val: 2023-08-08 to 2024-08-08 (248 obs)
# Test: 2024-08-08 to 2024-09-08 (21 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002427, QLIKE: 0.040594
# Out-of-sample MSE: 0.000465, QLIKE: 0.019541
#
# --- Window 293 ---
# Train: 1996-05-08 to 2023-09-08 (6859 obs)
# Val: 2023-09-08 to 2024-09-08 (247 obs)
# Test: 2024-09-08 to 2024-10-08 (22 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002388, QLIKE: 0.040461
# Out-of-sample MSE: 0.001032, QLIKE: 0.037780
#
# --- Window 294 ---
# Train: 1996-05-08 to 2023-10-08 (6878 obs)
# Val: 2023-10-08 to 2024-10-08 (249 obs)
# Test: 2024-10-08 to 2024-11-08 (23 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002381, QLIKE: 0.040631
# Out-of-sample MSE: 0.000242, QLIKE: 0.019875
#
# --- Window 295 ---
# Train: 1996-05-08 to 2023-11-08 (6901 obs)
# Val: 2023-11-08 to 2024-11-08 (249 obs)
# Test: 2024-11-08 to 2024-12-08 (20 obs)
# Training ensemble of 10 models...
# Training model 1/10
# Training model 2/10
# Training model 3/10
# Training model 4/10
# Training model 5/10
# Training model 6/10
# Training model 7/10
# Training model 8/10
# Training model 9/10
# Training model 10/10
# In-sample MSE: 0.002379, QLIKE: 0.040038
# Out-of-sample MSE: 0.000320, QLIKE: 0.030925
#
# Results saved to mlp_rv_forecast_results.csv
#
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
# Overall Out-of-Sample Performance:
# MSE: 0.002063
# QLIKE: 0.037488
#
# Average Performance Across Windows:
# In-Sample - MSE: 0.003076, QLIKE: 0.050896
# Out-of-Sample - MSE: 0.002045, QLIKE: 0.037581
#
# Correlation between Actual and Predicted: 0.8551
#
# Total number of expanding windows: 295
# Total predictions made: 6367
#
# Generating plots...
